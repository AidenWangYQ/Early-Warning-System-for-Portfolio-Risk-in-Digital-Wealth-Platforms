# %% [markdown]
# # Team 5 Final Pipeline
#
# This notebook is the **clean walkthrough** of the merged pipeline:
#
# 1. Data prep
# 2. Feature engineering
# 3. Modeling
# 4. Decision engine
# 5. Evaluation and charts
#
# It follows the stronger notebook-style modeling logic, while preserving the end-to-end flow from the original R script.

# %%
from pathlib import Path
import runpy
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)

# %% [markdown]
# ## Run `01_data_prep.py`

# %%
runpy.run_path('01_data_prep.py', run_name='__main__')

# %% [markdown]
# ## Run `02_feature_engineering.py`

# %%
runpy.run_path('02_feature_engineering.py', run_name='__main__')

# %% [markdown]
# ## Run `03_modeling.py`

# %%
runpy.run_path('03_modeling.py', run_name='__main__')

# %% [markdown]
# ## Run `04_decision_engine.py`

# %%
runpy.run_path('04_decision_engine.py', run_name='__main__')

# %% [markdown]
# ## Run `05_evaluation_and_charts.py`

# %%
runpy.run_path('05_evaluation_and_charts.py', run_name='__main__')

# %% [markdown]
# ## Outputs
#
# Check the `outputs/` folder for:
# - `master_dataset.csv`
# - `spy_model_dataset.csv`
# - `tlt_model_dataset.csv`
# - `predictions.csv`
# - `model_metrics.csv`
# - `warning_metrics.csv`
# - `portfolio_results.csv`
# - `portfolio_kpis.csv`
# - charts in `outputs/charts/`
